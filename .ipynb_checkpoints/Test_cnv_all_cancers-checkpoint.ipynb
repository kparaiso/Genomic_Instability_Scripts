# %%
# %matplotlib inline
import pandas as pd
from os.path import join
from os import walk, listdir
from collections import defaultdict
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA

pd.set_option("display.max_rows", 20)

# %cd C:/Users/wesle/OneDrive/College/Graeber Lab/Genomic_instability/Winter_2017/Thres_0.2_GSEA
# Out:
# C:\Users\wesle\OneDrive\College\Graeber Lab\Genomic_instability\Winter_2017\Thres_0.2_GSEA

# %%
WD = 'C:/Users/wesle/OneDrive/College/Graeber Lab/Genomic_instability/Winter_2017/Thres_0.2_GSEA/'
GSEA_DIR = [x[1] for x in walk(WD)][0]
GSEA_DIR
# Out:
# ['my_analysis_BKPT_CORE1.GseaPreranked.1490308521179',
#  'my_analysis_BKPT_CORE2.GseaPreranked.1490308515605',
#  'my_analysis_BRCA_18q_loss.Gsea.1485162750819',
#  'my_analysis_BRCA_1q_gain.Gsea.1485161112665',
#  'my_analysis_BRCA_3_loss.Gsea.1485161020010',
#  'my_analysis_BRCA_5q_gain.Gsea.1486529903187',
#  'my_analysis_BRCA_6q_gain.Gsea.1485162806106',
#  'my_analysis_BRCA_6q_loss.Gsea.1485160035043',
#  'my_analysis_BRCA_8p_loss.Gsea.1485161043026',
#  'my_analysis_BRCA_8q_gain.Gsea.1485161060694',
#  'my_analysis_BRCA_9p_loss.Gsea.1485161007838',
#  'my_analysis_ICNA_CORE1.GseaPreranked.1490308493201',
#  'my_analysis_ICNA_CORE2.GseaPreranked.1490308499576',
#  'my_analysis_SKCM_18q_loss.Gsea.1485163937477',
#  'my_analysis_SKCM_1q_gain.Gsea.1485162834098',
#  'my_analysis_SKCM_3_loss.Gsea.1485162853932',
#  'my_analysis_SKCM_5q_gain.Gsea.1486529916997',
#  'my_analysis_SKCM_6p_gain.Gsea.1485164033703',
#  'my_analysis_SKCM_6q_loss.Gsea.1485162916220',
#  'my_analysis_SKCM_8p_loss.Gsea.1485163902099',
#  'my_analysis_SKCM_8q_gain.Gsea.1485163920076',
#  'my_analysis_SKCM_9p_loss.Gsea.1485164068563',
#  'my_analysis_UVM_18q_loss.Gsea.1485159983262',
#  'my_analysis_UVM_1q_gain.Gsea.1485159929143',
#  'my_analysis_UVM_3_loss.Gsea.1485159076332',
#  'my_analysis_UVM_5q_gain.Gsea.1486529931251',
#  'my_analysis_UVM_6p_gain.Gsea.1485159953206',
#  'my_analysis_UVM_6q_loss.Gsea.1485159008321',
#  'my_analysis_UVM_8p_loss.Gsea.1485159027568',
#  'my_analysis_UVM_8q_gain.Gsea.1485159048798',
#  'my_analysis_UVM_9p_loss.Gsea.1485159100362']

# %%
all_cancers_cnv = pd.read_excel("All_cancers_CNV_NES_Score.xlsx", index_col=0)
cancer_groups = defaultdict(list)
cnv_groups = defaultdict(list)
cancer_columns = all_cancers_cnv.columns.tolist()
cancer_types = set(x.split("-")[0] for x in cancer_columns)
cnv_types = set("-".join(x.split("-")[1:]) for x in cancer_columns)
cancer_types
cnv_types
# Out:
# {'18q-loss',
#  '1q-gain',
#  '3-loss',
#  '5q-gain',
#  '6p-gain',
#  '6q-loss',
#  '8p-loss',
#  '8q-gain',
#  '9p-loss',
#  'BKPT-CORE1',
#  'BKPT-CORE2',
#  'ICNA-CORE1',
#  'ICNA-CORE2'}

# %%
def dict_map(dict_, keys, list_items):
    for k in keys:
        k_items = list(filter(lambda x: k in x, list_items))
        dict_[k] = k_items
    return dict_

# %%
cancer_groups = dict_map(cancer_groups, cancer_types, cancer_columns)
cnv_groups = dict_map(cnv_groups, cnv_types, cancer_columns)
cnv_groups
# Out:
# defaultdict(list,
#             {'18q-loss': ['BRCA-18q-loss', 'SKCM-18q-loss', 'UVM-18q-loss'],
#              '1q-gain': ['BRCA-1q-gain', 'SKCM-1q-gain', 'UVM-1q-gain'],
#              '3-loss': ['BRCA-3-loss', 'SKCM-3-loss', 'UVM-3-loss'],
#              '5q-gain': ['BRCA-5q-gain', 'SKCM-5q-gain', 'UVM-5q-gain'],
#              '6p-gain': ['BRCA-6p-gain', 'SKCM-6p-gain', 'UVM-6p-gain'],
#              '6q-loss': ['BRCA-6q-loss', 'SKCM-6q-loss', 'UVM-6q-loss'],
#              '8p-loss': ['BRCA-8p-loss', 'SKCM-8p-loss', 'UVM-8p-loss'],
#              '8q-gain': ['BRCA-8q-gain', 'SKCM-8q-gain', 'UVM-8q-gain'],
#              '9p-loss': ['BRCA-9p-loss', 'SKCM-9p-loss', 'UVM-9p-loss'],
#              'BKPT-CORE1': ['CORE1-BKPT-CORE1'],
#              'BKPT-CORE2': ['CORE2-BKPT-CORE2'],
#              'ICNA-CORE1': ['CORE1-ICNA-CORE1'],
#              'ICNA-CORE2': ['CORE2-ICNA-CORE2']})

# %%
def geneset_overlap_cancers(wd):
    gsea_dir = [x[1] for x in walk(wd)][0]
    all_cancer_cnv = pd.DataFrame()
    for i in range(len(gsea_dir)):
        cancer_cnv = '-'.join((gsea_dir[i].split('.')[0]).split('_')[2:])
        na_pos = ''
        na_neg = ''
        files_i = listdir(join(wd, gsea_dir[i]))
        wd_i = wd + gsea_dir[i]
        for f in files_i:
            if ("gsea_report_for_YES" in f or "gsea_report_for_na_pos" in f) and (".xls" in f):
                na_pos = f
            if ("gsea_report_for_NO" in f or "gsea_report_for_na_neg" in f) and (".xls" in f):
                na_neg = f
        df1 = pd.read_table(join(wd_i, na_pos), index_col=0)
        df2 = pd.read_table(join(wd_i, na_neg), index_col=0)
        df_i = pd.concat([df1, df2])
        # print(df_i['NES'])
        if (len(all_cancer_cnv.index)):
            all_cancer_cnv[cancer_cnv] = df_i['NES']
        else:
            all_cancer_cnv = pd.DataFrame(index=df_i.index)  
            all_cancer_cnv[cancer_cnv] = df_i['NES']
    # all_cancer_cnv.head()
    return all_cancer_cnv

# %%
all_cancer_cnv = geneset_overlap_cancers(WD)
all_cancer_cnv.columns
np.all(all_cancer_cnv["BRCA-5q-gain"] != np.nan)
all_cancer_cnv.to_excel(WD+"All_cancers_CNV_NES_Score__.xlsx")

# %%
# loading the data
all_cancers_cnv = pd.read_excel(WD+"All_cancers_CNV_NES_Score__.xlsx", index_col = 0, na_values=0)
all_cancers_cnv.head()
# Out:
#                                  BKPT-CORE1  BKPT-CORE2  BRCA-18q-loss  \
# NAME
# REACTOME_DNA_REPLICATION           3.851666    2.936207       2.074622
# REACTOME_MITOTIC_M_M_G1_PHASES     3.737821    2.808506       2.074693
# REACTOME_CELL_CYCLE_MITOTIC        3.710160    2.904587       1.810346
# REACTOME_CELL_CYCLE                3.702091    2.772370       1.943103
# REACTOME_CELL_CYCLE_CHECKPOINTS    3.521164    2.237758       1.854227
#
#                                  BRCA-1q-gain  BRCA-3-loss  BRCA-5q-gain  \
# NAME
# REACTOME_DNA_REPLICATION             1.694019     1.717907      0.802626
# REACTOME_MITOTIC_M_M_G1_PHASES       1.652025     1.656173      0.766315
# REACTOME_CELL_CYCLE_MITOTIC          1.593980     1.652680      0.914997
# REACTOME_CELL_CYCLE                  1.649298     1.657351      0.930743
# REACTOME_CELL_CYCLE_CHECKPOINTS      1.372519     1.606202      0.944640
#
#                                  BRCA-6q-gain  BRCA-6q-loss  BRCA-8p-loss  \
# NAME
# REACTOME_DNA_REPLICATION             2.153249      0.753963      1.999012
# REACTOME_MITOTIC_M_M_G1_PHASES       2.123906      0.661707      2.003650
# REACTOME_CELL_CYCLE_MITOTIC          2.098447      0.824911      1.921690
# REACTOME_CELL_CYCLE                  2.041116      1.333571      2.032968
# REACTOME_CELL_CYCLE_CHECKPOINTS      1.902379      0.596001      2.059232
#
#                                  BRCA-8q-gain     ...       SKCM-9p-loss  \
# NAME                                              ...
# REACTOME_DNA_REPLICATION             2.250175     ...          -0.917094
# REACTOME_MITOTIC_M_M_G1_PHASES       2.271612     ...          -0.967938
# REACTOME_CELL_CYCLE_MITOTIC          2.223563     ...          -0.953440
# REACTOME_CELL_CYCLE                  2.294861     ...          -0.943239
# REACTOME_CELL_CYCLE_CHECKPOINTS      2.169343     ...          -0.822806
#
#                                  UVM-18q-loss  UVM-1q-gain  UVM-3-loss  \
# NAME
# REACTOME_DNA_REPLICATION            -0.742689     0.977891    1.565459
# REACTOME_MITOTIC_M_M_G1_PHASES      -0.814286     1.038598    1.573884
# REACTOME_CELL_CYCLE_MITOTIC         -0.712193     0.999268    1.487552
# REACTOME_CELL_CYCLE                 -0.936619     1.041949    1.376301
# REACTOME_CELL_CYCLE_CHECKPOINTS     -0.763053     0.759250    1.533308
#
#                                  UVM-5q-gain  UVM-6p-gain  UVM-6q-loss  \
# NAME
# REACTOME_DNA_REPLICATION           -0.708245    -1.103086     1.261652
# REACTOME_MITOTIC_M_M_G1_PHASES     -0.713071    -1.095478     1.241473
# REACTOME_CELL_CYCLE_MITOTIC        -0.650107    -0.991520     1.094855
# REACTOME_CELL_CYCLE                -0.744996    -0.824154     1.267587
# REACTOME_CELL_CYCLE_CHECKPOINTS    -0.821339    -1.118153     1.495903
#
#                                  UVM-8p-loss  UVM-8q-gain  UVM-9p-loss
# NAME
# REACTOME_DNA_REPLICATION            1.208848     0.986936    -0.836578
# REACTOME_MITOTIC_M_M_G1_PHASES      1.242824     0.993845    -0.829262
# REACTOME_CELL_CYCLE_MITOTIC         1.084037     0.988767    -0.835948
# REACTOME_CELL_CYCLE                 1.064341     1.120562    -0.796664
# REACTOME_CELL_CYCLE_CHECKPOINTS     1.376446     1.083998    -0.771722
#
# [5 rows x 31 columns]

# %%
columns = all_cancers_cnv.columns.tolist()
cancers = [x.split("-")[0] for x in columns]
cnvs = ["-".join(x.split("-")[1:]) for x in columns]
cancer_list = [list(filter(lambda x : y in x, columns)) for y in cancers]
cnv_list = [list(filter(lambda x : y in x, columns)) for y in cnvs]
group_by_cancers = dict(zip(cancers, cancer_list))
group_by_cnv = dict(zip(cnvs, cnv_list))
cancer_groups = pd.MultiIndex.from_tuples([(k, v) for k in group_by_cancers for v in group_by_cancers[k]])
cnv_groups = pd.MultiIndex.from_tuples([(k, v) for k in group_by_cnv for v in group_by_cnv[k]])
cnv_groupby_cancers = all_cancer_cnv
cnv_groupby_cnvs = all_cancer_cnv
cnv_groupby_cancers.columns = cancer_groups
cnv_groupby_cnvs.columns = cnv_groups
# Out:
# ['CORE2',
#  'CORE2',
#  '5q-gain',
#  '5q-gain',
#  '5q-gain',
#  '6p-gain',
#  '6p-gain',
#  '8q-gain',
#  '8q-gain',
#  '8q-gain',
#  '1q-gain',
#  '1q-gain',
#  '1q-gain',
#  '6q-gain',
#  '6q-loss',
#  '6q-loss',
#  '6q-loss',
#  '9p-loss',
#  '9p-loss',
#  '9p-loss',
#  'CORE1',
#  'CORE1',
#  '18q-loss',
#  '18q-loss',
#  '18q-loss',
#  '3-loss',
#  '3-loss',
#  '3-loss',
#  '8p-loss',
#  '8p-loss',
#  '8p-loss']

# %%
variance_groupby_cnv = pd.DataFrame(index=cnv_groupby_cnvs.index)
cols_groupby_cnv = set([column[0] for column in cnv_groupby_cnvs])
for col in cols_groupby_cnv:
    variance_groupby_cnv[col + "-mean"] = cnv_groupby_cnvs[col].mean(axis=1)
    variance_groupby_cnv[col + "-std"] = cnv_groupby_cnvs[col].std(axis=1)
variance_groupby_cnv.to_excel(WD+"variance_groupby_cnv.xlsx")

# %%
# Out:
#                                                         CORE2             \
#                                                    BKPT-CORE2 ICNA-CORE2
# NAME
# REACTOME_DNA_REPLICATION                             3.851666   2.936207
# REACTOME_MITOTIC_M_M_G1_PHASES                       3.737821   2.808506
# REACTOME_CELL_CYCLE_MITOTIC                          3.710160   2.904587
# REACTOME_CELL_CYCLE                                  3.702091   2.772370
# REACTOME_CELL_CYCLE_CHECKPOINTS                      3.521164   2.237758
# REACTOME_S_PHASE                                     3.518623   2.252475
# REACTOME_SYNTHESIS_OF_DNA                            3.446647   2.226888
# REACTOME_MITOTIC_G1_G1_S_PHASES                      3.408904   2.241970
# REACTOME_G1_S_TRANSITION                             3.408838   2.197550
# REACTOME_M_G1_TRANSITION                             3.396993   1.994739
# ...                                                       ...        ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...  -0.584185  -1.171695
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...  -0.575721  -1.577106
# BIOCARTA_FREE_PATHWAY                               -0.572766  -1.540015
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...  -0.561152  -1.582990
# BIOCARTA_MAL_PATHWAY                                -0.556735  -0.557636
# REACTOME_SIGNALING_BY_NOTCH2                        -0.529013  -0.522028
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS            -0.490740   1.495826
# KEGG_GALACTOSE_METABOLISM                           -0.487282  -1.107934
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...  -0.481098   1.060939
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...  -0.461444   0.813575
#
#                                                         5q-gain               \
#                                                    BRCA-5q-gain SKCM-5q-gain
# NAME
# REACTOME_DNA_REPLICATION                               2.074622     1.694019
# REACTOME_MITOTIC_M_M_G1_PHASES                         2.074693     1.652025
# REACTOME_CELL_CYCLE_MITOTIC                            1.810346     1.593980
# REACTOME_CELL_CYCLE                                    1.943103     1.649298
# REACTOME_CELL_CYCLE_CHECKPOINTS                        1.854227     1.372519
# REACTOME_S_PHASE                                       1.878276     1.250655
# REACTOME_SYNTHESIS_OF_DNA                              1.991704     1.344124
# REACTOME_MITOTIC_G1_G1_S_PHASES                        1.800361     1.044588
# REACTOME_G1_S_TRANSITION                               1.914187     1.030263
# REACTOME_M_G1_TRANSITION                               1.963849     1.220285
# ...                                                         ...          ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...     1.212485    -1.015575
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...     0.576537    -1.367292
# BIOCARTA_FREE_PATHWAY                                  0.904906     0.912002
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...    -1.090601    -1.269720
# BIOCARTA_MAL_PATHWAY                                   1.055151    -1.192530
# REACTOME_SIGNALING_BY_NOTCH2                           0.716559     1.673354
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS               1.242327    -0.893076
# KEGG_GALACTOSE_METABOLISM                              1.083029    -1.179378
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...    -1.086273    -1.186004
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...    -1.298444    -1.192073
#
#                                                                     6p-gain  \
#                                                    UVM-5q-gain SKCM-6p-gain
# NAME
# REACTOME_DNA_REPLICATION                              1.717907     0.802626
# REACTOME_MITOTIC_M_M_G1_PHASES                        1.656173     0.766315
# REACTOME_CELL_CYCLE_MITOTIC                           1.652680     0.914997
# REACTOME_CELL_CYCLE                                   1.657351     0.930743
# REACTOME_CELL_CYCLE_CHECKPOINTS                       1.606202     0.944640
# REACTOME_S_PHASE                                      1.679468     1.054515
# REACTOME_SYNTHESIS_OF_DNA                             1.674959     0.821342
# REACTOME_MITOTIC_G1_G1_S_PHASES                       1.570738     0.912486
# REACTOME_G1_S_TRANSITION                              1.605347     1.052802
# REACTOME_M_G1_TRANSITION                              1.586651     0.568016
# ...                                                        ...          ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...    1.047830    -1.024271
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...   -1.483308    -1.080908
# BIOCARTA_FREE_PATHWAY                                 1.105243          NaN
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...    0.649042    -1.284291
# BIOCARTA_MAL_PATHWAY                                 -1.002939    -1.554643
# REACTOME_SIGNALING_BY_NOTCH2                         -1.099330     1.426615
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS             -1.497990    -0.814145
# KEGG_GALACTOSE_METABOLISM                            -0.622309    -1.286144
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...   -1.253851     1.107750
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...   -1.345834     1.206291
#
#                                                                     8q-gain  \
#                                                    UVM-6p-gain BRCA-8q-gain
# NAME
# REACTOME_DNA_REPLICATION                              2.153249     0.753963
# REACTOME_MITOTIC_M_M_G1_PHASES                        2.123906     0.661707
# REACTOME_CELL_CYCLE_MITOTIC                           2.098447     0.824911
# REACTOME_CELL_CYCLE                                   2.041116     1.333571
# REACTOME_CELL_CYCLE_CHECKPOINTS                       1.902379     0.596001
# REACTOME_S_PHASE                                      1.843890     0.818087
# REACTOME_SYNTHESIS_OF_DNA                             1.867279     0.736959
# REACTOME_MITOTIC_G1_G1_S_PHASES                       1.899587     0.617742
# REACTOME_G1_S_TRANSITION                              1.814078     0.651867
# REACTOME_M_G1_TRANSITION                              1.886949     0.482422
# ...                                                        ...          ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...    1.070090    -1.350823
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...    0.665753    -0.800736
# BIOCARTA_FREE_PATHWAY                                -0.631130    -0.999155
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...    1.189264    -1.383159
# BIOCARTA_MAL_PATHWAY                                 -1.017215     0.512835
# REACTOME_SIGNALING_BY_NOTCH2                         -0.965252    -0.975879
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS              0.796616    -0.867013
# KEGG_GALACTOSE_METABOLISM                             1.210034    -1.314383
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...   -0.799722    -0.674791
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...   -0.800651    -0.690910
#
#                                                                              \
#                                                    SKCM-8q-gain UVM-8q-gain
# NAME
# REACTOME_DNA_REPLICATION                               1.999012    2.250175
# REACTOME_MITOTIC_M_M_G1_PHASES                         2.003650    2.271612
# REACTOME_CELL_CYCLE_MITOTIC                            1.921690    2.223563
# REACTOME_CELL_CYCLE                                    2.032968    2.294861
# REACTOME_CELL_CYCLE_CHECKPOINTS                        2.059232    2.169343
# REACTOME_S_PHASE                                       2.021387    2.081370
# REACTOME_SYNTHESIS_OF_DNA                              2.027420    2.080361
# REACTOME_MITOTIC_G1_G1_S_PHASES                        1.786913    2.159418
# REACTOME_G1_S_TRANSITION                               1.872937    2.071372
# REACTOME_M_G1_TRANSITION                               2.036350    2.109460
# ...                                                         ...         ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...     1.038548    1.380323
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...    -0.963858    0.835421
# BIOCARTA_FREE_PATHWAY                                  0.784101   -0.753724
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...     0.784879    0.708013
# BIOCARTA_MAL_PATHWAY                                   1.126280    0.957823
# REACTOME_SIGNALING_BY_NOTCH2                          -0.960955   -1.267521
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS              -0.874131   -0.892247
# KEGG_GALACTOSE_METABOLISM                             -0.906903    0.830885
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...    -0.812551    0.682445
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...    -0.923340    0.612565
#
#                                                        ...          CORE1  \
#                                                        ...     ICNA-CORE1
# NAME                                                   ...
# REACTOME_DNA_REPLICATION                               ...      -0.917094
# REACTOME_MITOTIC_M_M_G1_PHASES                         ...      -0.967938
# REACTOME_CELL_CYCLE_MITOTIC                            ...      -0.953440
# REACTOME_CELL_CYCLE                                    ...      -0.943239
# REACTOME_CELL_CYCLE_CHECKPOINTS                        ...      -0.822806
# REACTOME_S_PHASE                                       ...      -0.871571
# REACTOME_SYNTHESIS_OF_DNA                              ...      -0.864408
# REACTOME_MITOTIC_G1_G1_S_PHASES                        ...      -0.997982
# REACTOME_G1_S_TRANSITION                               ...      -1.020806
# REACTOME_M_G1_TRANSITION                               ...      -0.850914
# ...                                                    ...            ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...     ...      -1.882502
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...     ...       0.653130
# BIOCARTA_FREE_PATHWAY                                  ...       0.744567
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...     ...       0.893632
# BIOCARTA_MAL_PATHWAY                                   ...      -1.252786
# REACTOME_SIGNALING_BY_NOTCH2                           ...       1.244325
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS               ...       0.782864
# KEGG_GALACTOSE_METABOLISM                              ...      -0.835675
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...     ...       1.275151
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...     ...       1.367379
#
#                                                         18q-loss  \
#                                                    BRCA-18q-loss
# NAME
# REACTOME_DNA_REPLICATION                               -0.742689
# REACTOME_MITOTIC_M_M_G1_PHASES                         -0.814286
# REACTOME_CELL_CYCLE_MITOTIC                            -0.712193
# REACTOME_CELL_CYCLE                                    -0.936619
# REACTOME_CELL_CYCLE_CHECKPOINTS                        -0.763053
# REACTOME_S_PHASE                                       -0.661781
# REACTOME_SYNTHESIS_OF_DNA                               0.742976
# REACTOME_MITOTIC_G1_G1_S_PHASES                        -0.590057
# REACTOME_G1_S_TRANSITION                               -0.677752
# REACTOME_M_G1_TRANSITION                               -0.791339
# ...                                                          ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...     -1.226650
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...      1.141580
# BIOCARTA_FREE_PATHWAY                                  -0.601858
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...     -0.484270
# BIOCARTA_MAL_PATHWAY                                   -1.369281
# REACTOME_SIGNALING_BY_NOTCH2                            0.782083
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS               -0.938830
# KEGG_GALACTOSE_METABOLISM                              -0.565049
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...     -1.036850
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...     -1.014684
#
#                                                                                \
#                                                    SKCM-18q-loss UVM-18q-loss
# NAME
# REACTOME_DNA_REPLICATION                                0.977891     1.565459
# REACTOME_MITOTIC_M_M_G1_PHASES                          1.038598     1.573884
# REACTOME_CELL_CYCLE_MITOTIC                             0.999268     1.487552
# REACTOME_CELL_CYCLE                                     1.041949     1.376301
# REACTOME_CELL_CYCLE_CHECKPOINTS                         0.759250     1.533308
# REACTOME_S_PHASE                                       -0.532932     1.634763
# REACTOME_SYNTHESIS_OF_DNA                               0.479063     1.632843
# REACTOME_MITOTIC_G1_G1_S_PHASES                         0.857723     1.591825
# REACTOME_G1_S_TRANSITION                                0.763815     1.636623
# REACTOME_M_G1_TRANSITION                                0.528093     1.602763
# ...                                                          ...          ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...      0.818647     0.805642
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...     -0.777372     1.321476
# BIOCARTA_FREE_PATHWAY                                   1.167883     1.228636
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...      0.557088     1.321223
# BIOCARTA_MAL_PATHWAY                                   -0.800543    -1.509813
# REACTOME_SIGNALING_BY_NOTCH2                           -1.070960     1.714960
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS               -1.252999     1.209428
# KEGG_GALACTOSE_METABOLISM                              -1.447304     1.215718
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...      0.560491     1.146410
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...     -0.482166     1.341672
#
#                                                         3-loss              \
#                                                    BRCA-3-loss SKCM-3-loss
# NAME
# REACTOME_DNA_REPLICATION                             -0.708245   -1.103086
# REACTOME_MITOTIC_M_M_G1_PHASES                       -0.713071   -1.095478
# REACTOME_CELL_CYCLE_MITOTIC                          -0.650107   -0.991520
# REACTOME_CELL_CYCLE                                  -0.744996   -0.824154
# REACTOME_CELL_CYCLE_CHECKPOINTS                      -0.821339   -1.118153
# REACTOME_S_PHASE                                     -0.636080   -1.230075
# REACTOME_SYNTHESIS_OF_DNA                            -0.675385   -1.288911
# REACTOME_MITOTIC_G1_G1_S_PHASES                      -0.768963   -1.177836
# REACTOME_G1_S_TRANSITION                             -0.755383   -1.210708
# REACTOME_M_G1_TRANSITION                             -0.804226   -1.235516
# ...                                                        ...         ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...   -0.925779   -1.074410
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...   -0.868394   -1.365369
# BIOCARTA_FREE_PATHWAY                                      NaN   -1.225996
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...   -0.816481   -0.968585
# BIOCARTA_MAL_PATHWAY                                  0.757155    1.696413
# REACTOME_SIGNALING_BY_NOTCH2                         -1.153792   -1.604217
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS              0.938020   -1.235265
# KEGG_GALACTOSE_METABOLISM                             0.883036   -1.359864
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...    0.595276   -1.161550
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...    0.623153   -1.274050
#
#                                                                    8p-loss  \
#                                                    UVM-3-loss BRCA-8p-loss
# NAME
# REACTOME_DNA_REPLICATION                             1.261652     1.208848
# REACTOME_MITOTIC_M_M_G1_PHASES                       1.241473     1.242824
# REACTOME_CELL_CYCLE_MITOTIC                          1.094855     1.084037
# REACTOME_CELL_CYCLE                                  1.267587     1.064341
# REACTOME_CELL_CYCLE_CHECKPOINTS                      1.495903     1.376446
# REACTOME_S_PHASE                                     1.400091     1.377947
# REACTOME_SYNTHESIS_OF_DNA                            1.376532     1.367065
# REACTOME_MITOTIC_G1_G1_S_PHASES                      1.199831     1.295097
# REACTOME_G1_S_TRANSITION                             1.316913     1.288935
# REACTOME_M_G1_TRANSITION                             1.498382     1.517027
# ...                                                       ...          ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...   0.864172     1.496723
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...   0.728004     1.710747
# BIOCARTA_FREE_PATHWAY                                0.835482     0.955561
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...   0.452601     0.960195
# BIOCARTA_MAL_PATHWAY                                 0.539882    -1.403628
# REACTOME_SIGNALING_BY_NOTCH2                         1.234707     0.906537
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS            -0.631127    -0.806744
# KEGG_GALACTOSE_METABOLISM                            1.045272     1.060991
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...   0.724344     0.955255
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...   0.801744     1.143479
#
#
#                                                    SKCM-8p-loss UVM-8p-loss
# NAME
# REACTOME_DNA_REPLICATION                               0.986936   -0.836578
# REACTOME_MITOTIC_M_M_G1_PHASES                         0.993845   -0.829262
# REACTOME_CELL_CYCLE_MITOTIC                            0.988767   -0.835948
# REACTOME_CELL_CYCLE                                    1.120562   -0.796664
# REACTOME_CELL_CYCLE_CHECKPOINTS                        1.083998   -0.771722
# REACTOME_S_PHASE                                       1.085798   -0.728855
# REACTOME_SYNTHESIS_OF_DNA                              1.018309   -0.734497
# REACTOME_MITOTIC_G1_G1_S_PHASES                        1.036920   -0.890008
# REACTOME_G1_S_TRANSITION                               1.066756   -0.745565
# REACTOME_M_G1_TRANSITION                               1.078505   -0.862120
# ...                                                         ...         ...
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION...    -0.953948   -1.246468
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACY...     1.389873    1.137806
# BIOCARTA_FREE_PATHWAY                                  1.634376    1.045814
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECE...     0.964151    1.252786
# BIOCARTA_MAL_PATHWAY                                  -1.029502   -1.563204
# REACTOME_SIGNALING_BY_NOTCH2                           0.814607    0.920900
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS               0.736956   -0.981648
# KEGG_GALACTOSE_METABOLISM                              1.322411   -1.154921
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACT...     1.243243    0.774285
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_O...     1.355022    0.852263
#
# [1324 rows x 31 columns]

# %%
# PCA plot
df = cnv_groupby_cnvs.T.fillna(0)
pca = PCA(n_components=4, whiten=True)
transf = pca.fit_transform(df)
variance_ratio = pca.explained_variance_ratio_
loadings = pca.components_
colName = [index[0] for index in df.index]
bar = pd.DataFrame(list(zip(transf[:, 0], transf[:, 1], colName)), columns=["PC1", "PC2", "Class"])
sns.lmplot("PC1", "PC2", bar, hue="Class", fit_reg=False, legend=False, size=8)
plt.xlabel("PC1: " + str(round(variance_ratio[0], 3)))
plt.ylabel("PC2: " + str(round(variance_ratio[1], 3)))
plt.legend(loc='best')
plt.title("PCA_plot_CNV_groupby_CNVs")
plt.savefig(WD+"PCA_plot_CNV_groupby_CNVs.jpg", bbox_inches='tight')
PCA_loadings = pd.DataFrame(loadings, index=["PC1", "PC2", "PC3", "PC4"], columns=df.columns.tolist())
PCA_loadings.to_csv(WD+"PCA_loadings_CNV_groupby_CNVs.txt", sep="\t")
# pca_norma = PCA(n_components=4, whiten=True)

# %%
# Correlation plot based on group by cancer and by cnv type
